# %%
import pandas as pd
df=pd.read_csv("IPL IMB381IPL2013.csv")

# %%
df
# Out:
#      Sl.NO.   PLAYER NAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0         1   Abdulla, YA    2      SA   KXIP   Allrounder       0       0
# 1         2  Abdur Razzak    2     BAN    RCB       Bowler     214      18
# 2         3   Agarkar, AB    2     IND    KKR       Bowler     571      58
# 3         4     Ashwin, R    1     IND    CSK       Bowler     284      31
# 4         5  Badrinath, S    2     IND    CSK      Batsman      63       0
# ..      ...           ...  ...     ...    ...          ...     ...     ...
# 125     126     Yadav, AS    2     IND     DC      Batsman       0       0
# 126     127   Younis Khan    2     PAK     RR      Batsman    6398       7
# 127     128  Yuvraj Singh    2     IND  KXIP+      Batsman    1775       9
# 128     129   Zaheer Khan    2     IND    MI+       Bowler    1114     288
# 129     130    Zoysa, DNT    2      SL     DC       Bowler     288      64
#
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # displaying first few records of dataframe

# %%
pd.set_option('display.max_columns', 10) 
df.head(5)
# Out:
#    Sl.NO.   PLAYER NAME  AGE COUNTRY  TEAM  ...   ECON  SR-BL  AUCTION YEAR  \
# 0       1   Abdulla, YA    2      SA  KXIP  ...   8.90  13.93          2009
# 1       2  Abdur Razzak    2     BAN   RCB  ...  14.50   0.00          2008
# 2       3   Agarkar, AB    2     IND   KKR  ...   8.81  24.90          2008
# 3       4     Ashwin, R    1     IND   CSK  ...   6.23  22.14          2011
# 4       5  Badrinath, S    2     IND   CSK  ...   0.00   0.00          2011
#
#    BASE PRICE  SOLD PRICE
# 0       50000       50000
# 1       50000       50000
# 2      200000      350000
# 3      100000      850000
# 4      100000      800000
#
# [5 rows x 26 columns]

# %%
df.sample(15)
# Out:
#      Sl.NO.     PLAYER NAME  AGE COUNTRY   TEAM  ...   ECON  SR-BL  \
# 93       94       Sehwag, V    2     IND     DD  ...  10.56  21.67
# 34       35   Henriques, MC    1     AUS   KKR+  ...   8.82  32.33
# 128     129     Zaheer Khan    2     IND    MI+  ...   7.75  21.26
# 26       27       Gayle, CH    2      WI   KKR+  ...   8.05  34.85
# 32       33      Hayden, ML    3     AUS    CSK  ...   0.00   0.00
# 116     117     Uthappa, RV    2     IND   RCB+  ...   0.00   0.00
# 122     123       Warne, SK    3     AUS     RR  ...   7.27  20.95
# 11       12  Chanderpaul, S    3      WI    RCB  ...   0.00   0.00
# 101     102       Singh, RP    2     IND    DC+  ...   7.75  19.78
# 123     124      Warner, DA    1     AUS     DD  ...   0.00   0.00
# 31       32      Harris, RJ    2     AUS    DC+  ...   7.71  17.27
# 3         4       Ashwin, R    1     IND    CSK  ...   6.23  22.14
# 124     125       White, CL    2     AUS   RCB+  ...  14.00   0.00
# ...

# %% [markdown]
# # finding meta data of dataframe

# %%
list(df.columns)
# Out:
# ['Sl.NO.',
#  'PLAYER NAME',
#  'AGE',
#  'COUNTRY',
#  'TEAM',
#  'PLAYING ROLE',
#  'T-RUNS',
#  'T-WKTS',
#  'ODI-RUNS-S',
#  'ODI-SR-B',
#  'ODI-WKTS',
#  'ODI-SR-BL',
#  'CAPTAINCY EXP',
#  'RUNS-S',
#  'HS',
#  'AVE',
#  'SR-B',
#  'SIXERS',
#  'RUNS-C',
#  'WKTS',
#  'AVE-BL',
#  'ECON',
#  'SR-BL',
#  'AUCTION YEAR',
#  'BASE PRICE',
#  'SOLD PRICE']

# %%
df.head(5).transpose()
# Out:
#                          0             1            2          3             4
# Sl.NO.                   1             2            3          4             5
# PLAYER NAME    Abdulla, YA  Abdur Razzak  Agarkar, AB  Ashwin, R  Badrinath, S
# AGE                      2             2            2          1             2
# COUNTRY                 SA           BAN          IND        IND           IND
# TEAM                  KXIP           RCB          KKR        CSK           CSK
# PLAYING ROLE    Allrounder        Bowler       Bowler     Bowler       Batsman
# T-RUNS                   0           214          571        284            63
# T-WKTS                   0            18           58         31             0
# ODI-RUNS-S               0           657         1269        241            79
# ODI-SR-B               0.0         71.41        80.62      84.56         45.93
# ODI-WKTS                 0           185          288         51             0
# ...

# %%
df.shape
# Out:
# (130, 26)

# %% [markdown]
# # Finding Summary of the Dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 26 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sl.NO.         130 non-null    int64
#  1   PLAYER NAME    130 non-null    object
#  2   AGE            130 non-null    int64
#  3   COUNTRY        130 non-null    object
#  4   TEAM           130 non-null    object
#  5   PLAYING ROLE   130 non-null    object
#  6   T-RUNS         130 non-null    int64
#  7   T-WKTS         130 non-null    int64
#  8   ODI-RUNS-S     130 non-null    int64
#  9   ODI-SR-B       130 non-null    float64
#  10  ODI-WKTS       130 non-null    int64
#  11  ODI-SR-BL      130 non-null    float64
#  12  CAPTAINCY EXP  130 non-null    int64
#  13  RUNS-S         130 non-null    int64
#  14  HS             130 non-null    int64
#  15  AVE            130 non-null    float64
#  16  SR-B           130 non-null    float64
# ...

# %% [markdown]
# # slicing and indexing the data frame

# %%
df[0:5]
# Out:
#    Sl.NO.   PLAYER NAME  AGE COUNTRY  TEAM  ...   ECON  SR-BL  AUCTION YEAR  \
# 0       1   Abdulla, YA    2      SA  KXIP  ...   8.90  13.93          2009
# 1       2  Abdur Razzak    2     BAN   RCB  ...  14.50   0.00          2008
# 2       3   Agarkar, AB    2     IND   KKR  ...   8.81  24.90          2008
# 3       4     Ashwin, R    1     IND   CSK  ...   6.23  22.14          2011
# 4       5  Badrinath, S    2     IND   CSK  ...   0.00   0.00          2011
#
#    BASE PRICE  SOLD PRICE
# 0       50000       50000
# 1       50000       50000
# 2      200000      350000
# 3      100000      850000
# 4      100000      800000
#
# [5 rows x 26 columns]

# %%
df[100:130]
# Out:
#      Sl.NO.       PLAYER NAME  AGE COUNTRY   TEAM  ...   ECON  SR-BL  \
# 100     101        Silva, LPC    2      SL     DC  ...  21.00   0.00
# 101     102         Singh, RP    2     IND    DC+  ...   7.75  19.78
# 102     103         Smith, DR    2      WI    DC+  ...   8.14  27.89
# 103     104         Smith, GC    2      SA    RR+  ...   0.00   0.00
# 104     105     Sohail Tanvir    2     PAK     RR  ...   6.46  11.20
# 105     106      Sreesanth, S    2     IND  KXIP+  ...   8.25  21.43
# 106     107         Steyn, DW    2      SA   RCB+  ...   6.58  20.15
# 107     108        Styris, SB    3      NZ    DC+  ...   7.67  27.00
# 108     109        Symonds, A    3     AUS    DC+  ...   7.70  26.35
# 109     110          Taibu, T    2     ZIM    KKR  ...   0.00   0.00
# 110     111      Taylor, LRPL    2      NZ   RCB+  ...  12.00   0.00
# 111     112     Tendulkar, SR    3     IND     MI  ...   9.67   0.00
# 112     113        Tiwary, MK    2     IND    DD+  ...  11.25  24.00
# ...

# %%
df[-5:]
# Out:
#      Sl.NO.   PLAYER NAME  AGE COUNTRY   TEAM  ...  ECON  SR-BL  AUCTION YEAR  \
# 125     126     Yadav, AS    2     IND     DC  ...  0.00   0.00          2010
# 126     127   Younis Khan    2     PAK     RR  ...  0.00   0.00          2008
# 127     128  Yuvraj Singh    2     IND  KXIP+  ...  7.02  21.13          2011
# 128     129   Zaheer Khan    2     IND    MI+  ...  7.75  21.26          2008
# 129     130    Zoysa, DNT    2      SL     DC  ...  9.00  33.00          2008
#
#      BASE PRICE  SOLD PRICE
# 125       50000      750000
# 126      225000      225000
# 127      400000     1800000
# 128      200000      450000
# 129      100000      110000
#
# [5 rows x 26 columns]

# %%
df[:-5]
# Out:
#      Sl.NO.     PLAYER NAME  AGE COUNTRY  TEAM  ...   ECON  SR-BL  \
# 0         1     Abdulla, YA    2      SA  KXIP  ...   8.90  13.93
# 1         2    Abdur Razzak    2     BAN   RCB  ...  14.50   0.00
# 2         3     Agarkar, AB    2     IND   KKR  ...   8.81  24.90
# 3         4       Ashwin, R    1     IND   CSK  ...   6.23  22.14
# 4         5    Badrinath, S    2     IND   CSK  ...   0.00   0.00
# ..      ...             ...  ...     ...   ...  ...    ...    ...
# 120     121     Vettori, DL    2      NZ   DD+  ...   6.81  27.75
# 121     122  Vinay Kumar, R    2     IND  RCB+  ...   8.24  19.87
# 122     123       Warne, SK    3     AUS    RR  ...   7.27  20.95
# 123     124      Warner, DA    1     AUS    DD  ...   0.00   0.00
# 124     125       White, CL    2     AUS  RCB+  ...  14.00   0.00
#
#      AUCTION YEAR  BASE PRICE  SOLD PRICE
# 0            2009       50000       50000
# 1            2008       50000       50000
# 2            2008      200000      350000
# ...

# %% [markdown]
# # selecting columns by columns names

# %%
df["PLAYER NAME"][0:5]
# Out:
# 0     Abdulla, YA
# 1    Abdur Razzak
# 2     Agarkar, AB
# 3       Ashwin, R
# 4    Badrinath, S
# Name: PLAYER NAME, dtype: object

# %%
df[["PLAYER NAME","AGE"]][0:8]
# Out:
#      PLAYER NAME  AGE
# 0    Abdulla, YA    2
# 1   Abdur Razzak    2
# 2    Agarkar, AB    2
# 3      Ashwin, R    1
# 4   Badrinath, S    2
# 5     Bailey, GJ    2
# 6      Balaji, L    2
# 7  Bollinger, DE    2

# %% [markdown]
# # selecting row and columns by indexes

# %%
df.iloc[4:9,1:9]
# Out:
#      PLAYER NAME  AGE COUNTRY  TEAM PLAYING ROLE  T-RUNS  T-WKTS  ODI-RUNS-S
# 4   Badrinath, S    2     IND   CSK      Batsman      63       0          79
# 5     Bailey, GJ    2     AUS   CSK      Batsman       0       0         172
# 6      Balaji, L    2     IND  CSK+       Bowler      51      27         120
# 7  Bollinger, DE    2     AUS   CSK       Bowler      54      50          50
# 8       Botha, J    2      SA    RR   Allrounder      83      17         609

# %% [markdown]
# # value counts and tabulations

# %%
df.TEAM.value_counts()
# Out:
# CSK      14
# RCB+     12
# KKR+     12
# DD+      10
# DC+      10
# RR+       9
# RCB       9
# DC        7
# KXIP+     7
# MI        6
# DD        6
# MI+       6
# RR        6
# CSK+      5
# KKR       5
# KXIP      5
# KXI+      1
# Name: TEAM, dtype: int64

# %%
df.COUNTRY.value_counts(normalize=True)
# Out:
# IND    0.407692
# AUS    0.169231
# SA     0.123077
# SL     0.092308
# PAK    0.069231
# NZ     0.053846
# WI     0.046154
# ENG    0.023077
# BAN    0.007692
# ZIM    0.007692
# Name: COUNTRY, dtype: float64

# %% [markdown]
# # cross tabulation between two columns

# %%
pd.crosstab(df['AGE'],df['PLAYING ROLE'] )
# Out:
# PLAYING ROLE  Allrounder  Batsman  Bowler  W. Keeper
# AGE
# 1                      4        5       7          0
# 2                     25       21      29         11
# 3                      6       13       8          1

# %% [markdown]
# # sorting dataframe by column values

# %%
df[['PLAYER NAME', 'SOLD PRICE']].sort_values('PLAYER NAME')[0:9]
# Out:
#      PLAYER NAME  SOLD PRICE
# 0    Abdulla, YA       50000
# 1   Abdur Razzak       50000
# 2    Agarkar, AB      350000
# 3      Ashwin, R      850000
# 4   Badrinath, S      800000
# 5     Bailey, GJ       50000
# 6      Balaji, L      500000
# 7  Bollinger, DE      700000
# 8       Botha, J      950000

# %%
df[['PLAYER NAME', 'SOLD PRICE','PLAYING ROLE']].sort_values('PLAYER NAME', ascending = False)[1:50]
# Out:
#           PLAYER NAME  SOLD PRICE PLAYING ROLE
# 129        Zoysa, DNT      110000       Bowler
# 128       Zaheer Khan      450000       Bowler
# 127      Yuvraj Singh     1800000      Batsman
# 126       Younis Khan      225000      Batsman
# 125         Yadav, AS      750000      Batsman
# 124         White, CL      500000      Batsman
# 123        Warner, DA      750000      Batsman
# 122         Warne, SK      450000       Bowler
# 121    Vinay Kumar, R      475000       Bowler
# 120       Vettori, DL      625000   Allrounder
# 119  Venugopal Rao, Y      700000      Batsman
# 118     Van der Merwe       50000   Allrounder
# 117       Vaas, WPUJC      200000       Bowler
# 116       Uthappa, RV      800000      Batsman
# 115          Umar Gul      150000       Bowler
# 114          Tyagi, S      240000       Bowler
# 113        Tiwary, SS     1600000      Batsman
# 112        Tiwary, MK      675000      Batsman
# 111     Tendulkar, SR     1800000      Batsman
# ...

# %% [markdown]
# # CREATING NEW COLUMNS

# %%
df['premium']=df['SOLD PRICE']-df['BASE PRICE']

# %%
df[['PLAYER NAME', 'BASE PRICE', 'SOLD PRICE', 'premium']][0:5]
# Out:
#     PLAYER NAME  BASE PRICE  SOLD PRICE  premium
# 0   Abdulla, YA       50000       50000        0
# 1  Abdur Razzak       50000       50000        0
# 2   Agarkar, AB      200000      350000   150000
# 3     Ashwin, R      100000      850000   750000
# 4  Badrinath, S      100000      800000   700000

# %%
df
# Out:
#      Sl.NO.   PLAYER NAME  AGE COUNTRY   TEAM  ...  SR-BL  AUCTION YEAR  \
# 0         1   Abdulla, YA    2      SA   KXIP  ...  13.93          2009
# 1         2  Abdur Razzak    2     BAN    RCB  ...   0.00          2008
# 2         3   Agarkar, AB    2     IND    KKR  ...  24.90          2008
# 3         4     Ashwin, R    1     IND    CSK  ...  22.14          2011
# 4         5  Badrinath, S    2     IND    CSK  ...   0.00          2011
# ..      ...           ...  ...     ...    ...  ...    ...           ...
# 125     126     Yadav, AS    2     IND     DC  ...   0.00          2010
# 126     127   Younis Khan    2     PAK     RR  ...   0.00          2008
# 127     128  Yuvraj Singh    2     IND  KXIP+  ...  21.13          2011
# 128     129   Zaheer Khan    2     IND    MI+  ...  21.26          2008
# 129     130    Zoysa, DNT    2      SL     DC  ...  33.00          2008
#
#      BASE PRICE  SOLD PRICE  premium
# 0         50000       50000        0
# ...

# %% [markdown]
# # Which players got the maximum premium offering on their base price

# %%
a=(df[['PLAYER NAME', 'BASE PRICE', 'SOLD PRICE', 'premium']].sort_values('premium', ascending = False)[0:5])

# %%
a.max()
# Out:
# PLAYER NAME    Yuvraj Singh
# BASE PRICE           400000
# SOLD PRICE          1800000
# premium             1650000
# dtype: object

# %%
df[['PLAYER NAME', 'BASE PRICE', 'SOLD PRICE', 'premium']].sort_values('premium', ascending = False)[0:5]
# Out:
#        PLAYER NAME  BASE PRICE  SOLD PRICE  premium
# 50        Kohli, V      150000     1800000  1650000
# 113     Tiwary, SS      100000     1600000  1500000
# 127   Yuvraj Singh      400000     1800000  1400000
# 111  Tendulkar, SR      400000     1800000  1400000
# 93       Sehwag, V      400000     1800000  1400000

# %% [markdown]
# # Grouping and Aggregating

# %% [markdown]
# What is the average SOLD PRICE for each age category?

# %%
df.groupby('AGE')['SOLD PRICE'].mean()
# Out:
# AGE
# 1    720250.000000
# 2    484534.883721
# 3    520178.571429
# Name: SOLD PRICE, dtype: float64

# %%
soldprice_by_age = df.groupby('AGE')['SOLD PRICE'].mean().reset_index() 
soldprice_by_age
# Out:
#    AGE     SOLD PRICE
# 0    1  720250.000000
# 1    2  484534.883721
# 2    3  520178.571429

# %% [markdown]
# # Average SOLD PRICE for Different Playing Roles in Each Age Category

# %%
soldprice_by_age_role=df.groupby(['AGE', 'PLAYING ROLE'])['SOLD PRICE'].mean().reset_index() 
soldprice_by_age_role
# Out:
#     AGE PLAYING ROLE    SOLD PRICE
# 0     1   Allrounder  5.875000e+05
# 1     1      Batsman  1.110000e+06
# 2     1       Bowler  5.177143e+05
# 3     2   Allrounder  4.494000e+05
# 4     2      Batsman  6.547619e+05
# 5     2       Bowler  3.979310e+05
# 6     2    W. Keeper  4.677273e+05
# 7     3   Allrounder  7.666667e+05
# 8     3      Batsman  4.576923e+05
# 9     3       Bowler  4.143750e+05
# 10    3    W. Keeper  7.000000e+05

# %% [markdown]
# # Joining dataframes

# %% [markdown]
# Compare the average auction price for different ages and playing role

# %%
soldprice_comparison = soldprice_by_age_role.merge( soldprice_by_age,on='AGE',how='outer')
soldprice_comparison
# Out:
#     AGE PLAYING ROLE  SOLD PRICE_x   SOLD PRICE_y
# 0     1   Allrounder  5.875000e+05  720250.000000
# 1     1      Batsman  1.110000e+06  720250.000000
# 2     1       Bowler  5.177143e+05  720250.000000
# 3     2   Allrounder  4.494000e+05  484534.883721
# 4     2      Batsman  6.547619e+05  484534.883721
# 5     2       Bowler  3.979310e+05  484534.883721
# 6     2    W. Keeper  4.677273e+05  484534.883721
# 7     3   Allrounder  7.666667e+05  520178.571429
# 8     3      Batsman  4.576923e+05  520178.571429
# 9     3       Bowler  4.143750e+05  520178.571429
# 10    3    W. Keeper  7.000000e+05  520178.571429
