# %%
import matplotlib.pyplot as plt
import numpy as np
plt.title("sales")
plt.xlabel("xaxis")
plt.ylabel("yaxis")
x=np.array([1,5,10])
y=np.array([2,6,11])
plt.plot(x,y)
plt.show()

# %%
x=[1,2,3]
y=[11,8,5]
plt.scatter(x,y)
plt.plot(x,y,marker="*",mec="red",linewidth="12",color="palegreen")
plt.show()

# %%
import pandas as pd
s=pd.Series([1,3,2,4,6])
s.describe()
# Out:
# count    5.000000
# mean     3.200000
# std      1.923538
# min      1.000000
# 25%      2.000000
# 50%      3.000000
# 75%      4.000000
# max      6.000000
# dtype: float64

# %%
import pandas as pd
a=pd.Series([1,3,20,4,6])
print(a.var())
print(a.mean())
print(a.std())
print(a.median())
# Out:
# 57.699999999999996
# 6.8
# 7.596051605933177
# 4.0

# %%
import pandas as pd
b=pd.Series([1,3,2,4,6])
print(b.var())
print(b.mean())
print(b.std())
print(b.median())
# Out:
# 3.7
# 3.2
# 1.9235384061671346
# 3.0

# %%
import pandas as pd
c=pd.Series([1,3,2,4,6])
c.describe()
# Out:
# count    5.000000
# mean     3.200000
# std      1.923538
# min      1.000000
# 25%      2.000000
# 50%      3.000000
# 75%      4.000000
# max      6.000000
# dtype: float64

# %%
import pandas as pd
d=pd.Series([9,3,2,4,6])
d.describe()
# Out:
# count    5.000000
# mean     4.800000
# std      2.774887
# min      2.000000
# 25%      3.000000
# 50%      4.000000
# 75%      6.000000
# max      9.000000
# dtype: float64

# %%
import pandas as pd
e=pd.Series([5,3,2,4,8])
e.describe()
# Out:
# count    5.000000
# mean     4.400000
# std      2.302173
# min      2.000000
# 25%      3.000000
# 50%      4.000000
# 75%      5.000000
# max      8.000000
# dtype: float64

# %%
import pandas as pd
f=pd.Series([5,6,0,4,11])
f.describe()
# Out:
# count     5.000000
# mean      5.200000
# std       3.962323
# min       0.000000
# 25%       4.000000
# 50%       5.000000
# 75%       6.000000
# max      11.000000
# dtype: float64

# %%
import matplotlib.pyplot as plt
import pandas as pd
p=[c.mean(),d.mean(),e.mean(),f.mean()]
plt.pie(p,labels=["c mean","d mean","e mean","f mean"],autopct='%1.1f%%')
plt.legend(loc='lower right')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
p=[c.mean(),c.var(),e.median(),f.std()]
plt.pie(p,labels=["mean","var","median","std"],autopct='%1.1f%%')
plt.legend(loc='lower left')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
p=[d.mean(),d.var(),d.median(),d.std()]
plt.pie(p,labels=["mean","var","median","std"],autopct='%1.1f%%')
plt.legend(loc='lower left')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
p=[e.mean(),e.var(),e.median(),e.std()]
plt.pie(p,labels=["mean","var","median","std"],autopct='%1.1f%%')
plt.legend(loc='lower left')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
p=[f.mean(),f.var(),f.median(),f.std()]
plt.pie(p,labels=["mean","var","median","std"],autopct='%1.1f%%')
plt.legend(loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt
x=[c.mean(),d.mean(),e.mean(),f.mean()]
y=[c.var(),d.var(),e.var(),f.var()]
plt.bar(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
x=[c.mean(),d.mean(),e.mean(),f.mean()]
y=[c.var(),d.var(),e.var(),f.var()]
cp=["r","g","y","b"]
plt.bar(x,y,color=cp)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
cv=[c.mean(),d.mean(),e.mean(),f.mean()]
plt.pie(cv,labels=["cmean","dmean","emean","fmean"],autopct='%1.1f%%')
plt.legend(loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt
xx=[c.mean(),d.mean(),e.mean(),f.mean()]
yy=[c.var(),d.var(),e.var(),f.var()]
cpp=["r","g","y","b"]
plt.scatter(x,y,s=1000,marker="*",color=cpp,alpha=0.8,edgecolor="red",linewidth=30)
plt.show()

# %%
]
